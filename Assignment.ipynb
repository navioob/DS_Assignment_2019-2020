# %% [markdown]
# # Data Science Assignment Part B
#
# Name:                          ID:
# Low Seh Hong                   1161104400
# Boo Ee Kein Ivan               1161104032
#
# From the previous report, we have formulated some questions regarding the topic that we are going to dive into:
#
# ## Formulated Question
# Does the unemployment rate have an impact towards the economic growth of the United States?
#
# ## Exploratory Questions
# 1. Does the level of education influence the rate of employment in the United States?
# 2. Does the rate of employment correlates with the growth of the economy?
# 3. Are the employment status and the level of education of the people something that is very important to the country?
#
# ## Predictive Questions
# 1. What will be the predicted growth of the country’s economy in 2019 based on the relationships with the past patterns of data on employment rate and unemployment rate based on education level?

# %% [markdown]
# ## Identifying and Collecting the data
# There are several datasets to be read in order to perform analysis:
#
# #### 1. GDPCountries.csv
#
# It contains the GDP growth rate of different countries from 1960 to 2018.
#
# https://data.worldbank.org/indicator/NY.GDP.MKTP.KD.ZG?locations=US
#
# World Bank national accounts data, and OECD National Accounts data files.
#
# #### 2. GDPValue.csv
#
# It contains the GDP value of different countries from 1960 to 2018.
#
# https://data.worldbank.org/indicator/NY.GDP.MKTP.KD.ZG?locations=US
#
# World Bank national accounts data, and OECD National Accounts data files.
#
# #### 3. Employment_level_less_highschool.csv
#
# It contains the employment level for individuals that have educational level lesser than highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 4. Employment_level_highschool.csv
#
# It contains the employment level for individuals that have educational level at most highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 5. Employment_level_college.csv
#
# It contains the employment level for individuals that have educational level at most college in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 6. Employment_level_degree_above.csv
#
# It contains the employment level for individuals that have educational level at degree and above in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 7. Unemployment_level_less_highschool.csv
#
# It contains the unemployment level for individuals that have educational level lesser than highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 8. Unemployment_level_highschool.csv
#
# It contains the unemployment level for individuals that have educational level at most highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 9. Unemployment_level_college.csv
#
# It contains the unemployment level for individuals that have educational level at most college in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm
#
# #### 10. Unemployment_level_degree_above.csv
#
# It contains the unemployment level for individuals that have educational level at degree and above in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %% [markdown]
# ## Cleaning the data
# First and foremost, we take a look at the dataset GDPCountries.csv and perform some basic cleaning and retrieve the data for the United States only.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We will retrieved only the data regarding the United States as our data analysis is foucused only on United States.

# %%
countryGDP_percent = pd.read_csv('GDPcountries.csv')
countryGDP_value = pd.read_csv('GDPvalue.csv')
empt_lvl_less_highschool = pd.read_csv('Employment_level_less_highschool.csv')
empt_lvl_highschool = pd.read_csv('Employment_level_highschool.csv')
empt_lvl_college = pd.read_csv('Employment_level_college.csv')
empt_lvl_degree_above = pd.read_csv('Employment_level_degree_above.csv')
unempt_lvl_less_highschool = pd.read_csv('Unemployment_level_less_highschool.csv')
unempt_lvl_highschool = pd.read_csv('Unemployment_level_highschool.csv')
unempt_lvl_college = pd.read_csv('Unemployment_level_college.csv')
unempt_lvl_degree_above = pd.read_csv('Unemployment_level_degree_above.csv')

# %% [markdown]
# ### Cleaning Data for GDPcountries.csv and GDPvalue.csv
#
# 1. First, we will make the index of countryGDP to follow the names of the Countries.
# 2. Then, we will take the row which contains the data of the United States and read them into seperate dataframe.
# 3. We will now check do we have null values and so we can prevent misleading data in our analysis later on.
# 4. As we can see there's 2 NaN values which is in 1960 and 2019. To make sure that the 2 years are the only NaN values, we will perform the sum of total NaN values of the whole dataframe.
# 5. So it is true that the NaN values are only in 1960 and 2019. And so, we will remove both of the columns to prevent misleading data anaylising. Besides, we will also remove the unused columns of the dataset.
# 6. Now, we will reshuffle the dataframe to have the year as row values and index.

# %% [markdown]
# ### Cleaning Data of GDPcountries.csv

# %%
countryGDP_percent.set_index('Country Name',inplace = True)
usaGDP_percent = countryGDP_percent.loc[['United States']]
print(usaGDP_percent.head())
# Out:
#               Country Code         Indicator Name     Indicator Code  1960  \
# Country Name
# United States          USA  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#                1961  1962  1963  1964  1965  1966  ...      2010      2011  \
# Country Name                                       ...
# United States   2.3   6.1   4.4   5.8   6.4   6.5  ...  2.563767  1.550836
#
#                    2012      2013      2014     2015      2016     2017  \
# Country Name
# United States  2.249546  1.842081  2.451973  2.88091  1.567215  2.21701
#
#                    2018  2019
# Country Name
# United States  2.927323   NaN
#
# [1 rows x 63 columns]

# %%
usaGDP_percent.isnull().sum()
# Out:
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              1
# 1961              0
#                  ..
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              1
# Length: 63, dtype: int64

# %%
usaGDP_percent.drop(['Country Code','Indicator Name','Indicator Code','1960','2019'],axis = 1, 
                    inplace = True)
usaGDP_percent = pd.melt(usaGDP_percent,var_name = 'Year',value_name = 'GDP_percent')
usaGDP_percent.set_index('Year', inplace = True)
usaGDP_percent.index = usaGDP_percent.index.astype('int64')
print(usaGDP_percent.head())
print(usaGDP_percent.tail())
# Out:
#       GDP_percent
# Year
# 1961          2.3
# 1962          6.1
# 1963          4.4
# 1964          5.8
# 1965          6.4
#       GDP_percent
# Year
# 2014     2.451973
# 2015     2.880910
# 2016     1.567215
# 2017     2.217010
# 2018     2.927323

# %% [markdown]
# ### Cleaning Data of GDPvalue.csv

# %%
countryGDP_value.set_index('Country Name',inplace = True)
usaGDP_value = countryGDP_value.loc[['United States']]
usaGDP_value.drop(['Country Code','Indicator Name','Indicator Code','1960','2019'],axis = 1, 
                  inplace = True)
usaGDP_value = pd.melt(usaGDP_value,var_name = 'Year',value_name = 'GDP_value')
usaGDP_value.set_index('Year', inplace = True)
usaGDP_value.index = usaGDP_value.index.astype('int64')
print(usaGDP_value.head())
# Out:
#          GDP_value
# Year
# 1961  5.633000e+11
# 1962  6.051000e+11
# 1963  6.386000e+11
# 1964  6.858000e+11
# 1965  7.437000e+11

# %% [markdown]
# ### Cleaning data for Employment_level_less_highschool.csv

# %% [markdown]
# After cleaning the data for GDPcountries.csv, we have succesfully extracted the growth rate of GDP for the United States, we will the clean the following data sets which the employment and unemployment levels with different attainment levels of education in the United States.
#
# First, we will read in the first .csv file for data cleaning.
#
# 1. Employment_level_less_highschool.csv
#
# It contains the employment level for individuals that have educational level lesser than highschool in thousands in USA from 1992 to 2019.

# %%
empt_lvl_less_highschool.tail()
# Out:
#     Year    Jan     Feb      Mar      Apr     May     Jun     Jul     Aug  \
# 24  2016  10101  9976.0  10059.0  10021.0  9710.0  9771.0  9899.0  9912.0
# 25  2017   9678  9501.0   9521.0   9439.0  9707.0  9658.0  9821.0  9867.0
# 26  2018   9710  9673.0   9676.0   9717.0  9719.0  9925.0  9682.0  9699.0
# 27  2019   9468  9721.0   9532.0   9453.0  9383.0  9482.0  9458.0  9478.0
# 28  2020   9090     NaN      NaN      NaN     NaN     NaN     NaN     NaN
#
#        Sep     Oct     Nov     Dec
# 24  9829.0  9871.0  9755.0  9684.0
# 25  9859.0  9732.0  9698.0  9508.0
# 26  9620.0  9676.0  9647.0  9654.0
# 27  9440.0  9240.0  9245.0  9379.0
# 28     NaN     NaN     NaN     NaN

# %% [markdown]
# We will want to check the sum of NaN value in the dataset.

# %%
empt_lvl_less_highschool.isnull().sum()
# Out:
# Year    0
# Jan     0
# Feb     1
# Mar     1
# Apr     1
# May     1
# Jun     1
# Jul     1
# Aug     1
# Sep     1
# Oct     1
# Nov     1
# Dec     1
# dtype: int64

# %% [markdown]
# There are only one NaN value from Feb until Dec, which the previous tail view of the data set, we know that all the NaN value confide in the row of Year 2020, which makes sense as the data is not yet available. With that, we will remove the last row and check again.

# %%
empt_lvl_less_highschool.drop([28], axis = 0 , inplace = True)

# %% [markdown]
# Since it has been removed, we will check again with the sum of NaN values in the dataframe.

# %%
empt_lvl_less_highschool.isnull().sum()
# Out:
# Year    0
# Jan     0
# Feb     0
# Mar     0
# Apr     0
# May     0
# Jun     0
# Jul     0
# Aug     0
# Sep     0
# Oct     0
# Nov     0
# Dec     0
# dtype: int64

# %% [markdown]
# Now, for our analysis, we want to take values for the year but not the month. So, we will find the mean for each year. First, we will set the index to Year, then proceed with our calculation.

# %%
empt_lvl_less_highschool.set_index('Year',inplace = True)
empt_lvl_less_highschool['Emp_Less_Highschool'] = empt_lvl_less_highschool.mean(axis = 1)

# %% [markdown]
# We will then drop the columns of the months as we only needed the mean anually.

# %%
empt_lvl_less_highschool.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %%
empt_lvl_less_highschool.head()
# Out:
#       Emp_Less_Highschool
# Year
# 1992         11844.833333
# 1993         11203.166667
# 1994         11055.416667
# 1995         10945.666667
# 1996         11314.916667

# %% [markdown]
# We will do the same data cleaning process of the following files as the files are from the same sources.

# %% [markdown]
# ### Cleaning Data for Employment_level_highschool.csv

# %% [markdown]
# 2. Employment_level_highschool.csv
#
# It contains the employment level for individuals that have educational level at most highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
empt_lvl_highschool.drop([28], axis = 0 , inplace = True)
empt_lvl_highschool.set_index('Year',inplace = True)
empt_lvl_highschool['Emp_Highschool'] = empt_lvl_highschool.mean(axis = 1)
empt_lvl_highschool.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# ### Cleaning Data for Employment_level_college.csv

# %% [markdown]
#  3. Employment_level_college.csv
#
# It contains the employment level for individuals that have educational level at most college in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment.
# https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
empt_lvl_college.drop([28], axis = 0 , inplace = True)
empt_lvl_college.set_index('Year',inplace = True)
empt_lvl_college['Emp_College'] = empt_lvl_college.mean(axis = 1)
empt_lvl_college.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# ### Cleaning Data for Employment_level_degree_above.csv

# %% [markdown]
# 4. Employment_level_degree_above.csv
#
# It contains the employment level for individuals that have educational level at degree and above in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment. https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
empt_lvl_degree_above.drop([28], axis = 0 , inplace = True)
empt_lvl_degree_above.set_index('Year',inplace = True)
empt_lvl_degree_above['Emp_Degree_Above'] = empt_lvl_degree_above.mean(axis = 1)
empt_lvl_degree_above.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# ### Cleaning Data for Unemployment_level_less_highschool.csv

# %% [markdown]
# 5. Unemployment_level_less_highschool.csv
#
# It contains the unemployment level for individuals that have educational level lesser than highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment. https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
unempt_lvl_less_highschool.drop([28], axis = 0 , inplace = True)
unempt_lvl_less_highschool.set_index('Year',inplace = True)
unempt_lvl_less_highschool['Uemp_Less_Highschool'] = unempt_lvl_less_highschool.mean(axis = 1)
unempt_lvl_less_highschool.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# ### Cleaning Data for Unemployment_level_highschool.csv

# %% [markdown]
# 6. Unemployment_level_highschool.csv
#
# It contains the unemployment level for individuals that have educational level at most highschool in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment. https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
unempt_lvl_highschool.drop([28], axis = 0 , inplace = True)
unempt_lvl_highschool.set_index('Year',inplace = True)
unempt_lvl_highschool['Uemp_Highschool'] = unempt_lvl_highschool.mean(axis = 1)
unempt_lvl_highschool.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# ### Cleaning Data for Unemployment_level_college.csv

# %% [markdown]
# 7. Unemployment_level_college.csv
#
# It contains the unemployment level for individuals that have educational level at most college in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment. https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
unempt_lvl_college.drop([28], axis = 0 , inplace = True)
unempt_lvl_college.set_index('Year',inplace = True)
unempt_lvl_college['Uemp_College'] = unempt_lvl_college.mean(axis = 1)
unempt_lvl_college.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# ### Cleaning Data for Unemployment_level_degree_above.csv

# %% [markdown]
# 8. Unemployment_level_degree_above.csv
#
# It contains the unemployment level for individuals that have educational level at degree and above in thousands in USA from 1992 to 2019.
#
# The data set is about the employment status of the civilian population 25 years and over by educational attainment. https://www.bls.gov/webapps/legacy/cpsatab4.htm

# %%
unempt_lvl_degree_above.drop([28], axis = 0 , inplace = True)
unempt_lvl_degree_above.set_index('Year',inplace = True)
unempt_lvl_degree_above['Uemp_Degree_Above'] = unempt_lvl_degree_above.mean(axis = 1)
unempt_lvl_degree_above.drop(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
                              axis = 1 , inplace = True)

# %% [markdown]
# # Merging All the Data

# %%
empt_merge_lesshighschool_highschool = pd.merge(empt_lvl_less_highschool,empt_lvl_highschool,
                                                on = 'Year', how= 'left')
empt_merge_college_degree_above = pd.merge(empt_lvl_college,empt_lvl_degree_above, 
                                           on = 'Year', how= 'left')
empt_merge_all = pd.merge(empt_merge_lesshighschool_highschool,empt_merge_college_degree_above, 
                          on = 'Year', how= 'left')
unempt_merge_lesshighschool_highschool = pd.merge(unempt_lvl_less_highschool,unempt_lvl_highschool, 
                                                  on = 'Year', how= 'left')
unempt_merge_college_degree_above = pd.merge(unempt_lvl_college,unempt_lvl_degree_above, 
                                             on = 'Year', how= 'left')
umempt_merge_all = pd.merge(unempt_merge_lesshighschool_highschool,unempt_merge_college_degree_above, 
                            on = 'Year', how= 'left')
merge_all_empt_umempt = pd.merge(empt_merge_all,umempt_merge_all, 
                                 on = 'Year', how= 'left')
merge_GDP_percent_value = pd.merge(usaGDP_percent,usaGDP_value, 
                                   on ='Year', how = 'left')
merge_GDP_all_empt_umempt = merge_all_empt_umempt.join(merge_GDP_percent_value)

# %% [markdown]
# We will then remove the rows that contains NaN values in order to get the final dataframe that we are to analyze.

# %%
merge_GDP_all_empt_umempt.dropna(inplace=True)

# %% [markdown]
# Z-Score Normalization

# %%
for col in merge_GDP_all_empt_umempt.columns[0: len(merge_GDP_all_empt_umempt.columns)-1]:
    merge_GDP_all_empt_umempt[col] = (merge_GDP_all_empt_umempt[col] - merge_GDP_all_empt_umempt[col]
                                      .mean())/merge_GDP_all_empt_umempt[col].std(ddof=0)

# %%
merge_GDP_all_empt_umempt.head()
# Out:
#       Emp_Less_Highschool  Emp_Highschool  Emp_College  Emp_Degree_Above  \
# Year
# 1992             1.214580        0.105672    -2.573144         -1.656498
# 1993             0.390005        0.191049    -2.082459         -1.550855
# 1994             0.200139       -0.048740    -1.443474         -1.407799
# 1995             0.059104       -0.177961    -1.091841         -1.262764
# 1996             0.533610        0.111810    -0.979487         -1.130993
#
#       Uemp_Less_Highschool  Uemp_Highschool  Uemp_College  Uemp_Degree_Above  \
# Year
# 1992              1.452880         0.685218     -0.144416          -0.576249
# 1993              0.877734         0.364093     -0.215442          -0.662400
# 1994              0.351353        -0.181096     -0.452905          -0.834351
# 1995             -0.033071        -0.518616     -0.624007          -0.853515
# 1996             -0.037677        -0.550575     -0.723550          -0.937732
#
#       GDP_percent     GDP_value
# Year
# ...

# %% [markdown]
# ## Analyzing the Data
# In this section we will try to find and analyze the underlying relationships from the data so that we are able to get a grasp on how should we use our data to make actionable insights.

# %%
merge_GDP_all_empt_umempt.corr()
# Out:
#                       Emp_Less_Highschool  Emp_Highschool  Emp_College  \
# Emp_Less_Highschool              1.000000        0.911767    -0.611757
# Emp_Highschool                   0.911767        1.000000    -0.368294
# Emp_College                     -0.611757       -0.368294     1.000000
# Emp_Degree_Above                -0.765137       -0.555008     0.945636
# Uemp_Less_Highschool            -0.116060       -0.290200    -0.305158
# Uemp_Highschool                 -0.442982       -0.533526     0.070418
# Uemp_College                    -0.614309       -0.652532     0.326413
# Uemp_Degree_Above               -0.750386       -0.733589     0.534534
# GDP_percent                      0.359198        0.287502    -0.419791
# GDP_value                       -0.775593       -0.572284     0.938056
#
#                       Emp_Degree_Above  Uemp_Less_Highschool  Uemp_Highschool  \
# Emp_Less_Highschool          -0.765137             -0.116060        -0.442982
# ...

# %%
merge_temp = merge_GDP_all_empt_umempt.drop(['GDP_percent'], axis = 1)

# %%
sns.heatmap(merge_temp.corr(), cmap='GnBu')

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Emp_Less_Highschool'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Emp_Highschool'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Emp_College'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Emp_Degree_Above'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Uemp_Less_Highschool'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Uemp_Highschool'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Uemp_College'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %%
sns.regplot(x= merge_GDP_all_empt_umempt['Uemp_Degree_Above'], y= merge_GDP_all_empt_umempt['GDP_value'], data=merge_GDP_all_empt_umempt)

# %% [markdown]
# ## Exploratory Questions
#
# 1. Does the level of education influence the rate of employment in the United States?
# 2. Does the rate of employment correlates with the growth of the economy?
# 3. Are the employment status and the level of education of the people something that is very important to the country?

# %% [markdown]
# 1. Does the level of education influence the rate of employment in the United States?

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.xaxis.set_ticks(np.arange(1992,2019, 1))
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_Less_Highschool'], label="$Employment Level (Less Than HighSchool$)")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_Highschool'], label="$Employment Level (HighSchool)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_College'], label="$Employment Level (College)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_Degree_Above'], label="$Employment Level (Degree and Above)$")
ax.legend(loc=0) # upper left corner
ax.set_xlabel('$Year$')
ax.set_ylabel('$Z-score$')
ax.set_title('Employment Level of Different Education Attainment from 1992 to 2018');

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.xaxis.set_ticks(np.arange(1992,2019, 1))

ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_Less_Highschool'], label="$Unemployment Level (Less Than HighSchool$)")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_Highschool'], label="$Unemployment Level (HighSchool)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_College'], label="$Unemployment Level (College)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_Degree_Above'], label="$Unemployment Level (Degree and Above)$")
ax.legend(loc=0) # upper left corner
ax.set_xlabel('$Year$')
ax.set_ylabel('$Z-score$')
ax.set_title('Unemployment Level of Different Education Attainment from 1992 to 2018');

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.xaxis.set_ticks(np.arange(1992,2019, 1))
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_Less_Highschool'], label="$Employment Level (Less Than HighSchool$)")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_Highschool'], label="$Employment Level (HighSchool)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_College'], label="$Employment Level (College)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Emp_Degree_Above'], label="$Employment Level (Degree and Above)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['GDP_percent'], label="$GDP%$")
ax.legend(loc=0) # upper left corner
ax.set_xlabel('$Year$')
ax.set_ylabel('$Z-score$')
ax.set_title('Employment Level of Different Education Attainment from 1992 to 2018 Compare with GDP %');

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.xaxis.set_ticks(np.arange(1992,2019, 1))

ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_Less_Highschool'], label="$Unemployment Level (Less Than HighSchool$)")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_Highschool'], label="$Unemployment Level (HighSchool)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_College'], label="$Unemployment Level (College)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['Uemp_Degree_Above'], label="$Unemployment Level (Degree and Above)$")
ax.plot(merge_GDP_all_empt_umempt.index,merge_GDP_all_empt_umempt['GDP_percent'], label="$GDP%$")
ax.legend(loc=0) # upper left corner
ax.set_xlabel('$Year$')
ax.set_ylabel('$Z-score$')
ax.set_title('Unemployment Level of Different Education Attainment from 1992 to 2018 Compare with GDP%');

# %% [markdown]
# ## Predictive Analysis
#
# In this case we will use Linear Regression as the method to create our predictive model. We will remove the GDP_percent as it does not serves as a descriptor for our data that is going to be trained and tested.

# %%
X = merge_GDP_all_empt_umempt.drop(['GDP_value','GDP_percent'], axis = 1 )
y = merge_GDP_all_empt_umempt['GDP_value'].copy()

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
reg = LinearRegression().fit(X_train, y_train)

reg.score(X_test, y_test)
# Out:
# 0.9976879084630039

# %% [markdown]
# Now, we will test it with the testing set.

# %%
some_data = X_test.iloc[:5]    # take first 5 entries from X_test
predicted_gdp = reg.predict(some_data)
predicted_gdp
# Out:
# array([1.45996136e+13, 1.36760569e+13, 1.48534408e+13, 7.59486797e+12,
#        1.84287812e+13])

# %% [markdown]
# We will compare it to the y_test which contains the 'Ground Truth' with the predicted values.

# %%
actual_gdp = y_test.iloc[:5].values    
actual_gdp
# Out:
# array([1.44489e+13, 1.38146e+13, 1.49921e+13, 7.63975e+12, 1.82193e+13])

# %% [markdown]
# To calculate the mean of this error across all test data, we calculate what is known as Mean Absolute Erorr (MAE), which tells us the amount of error made by the trained model. The lower this value, the better or more accurate the model is.

# %%
from sklearn.metrics import mean_absolute_error

y_prediction = reg.predict(X_test)
model_mae = mean_absolute_error(y_test, y_prediction)
print(model_mae)
# Out:
# 139148255282.06625

# %%
from sklearn.metrics import mean_squared_error
model_mse = mean_squared_error(y_test, y_prediction)
print(model_mse)
# Out:
# 2.4194187518025832e+22

# %%
emp_lvl_less_highschool.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b0896c063670> in <module>
# ----> 1 emp_lvl_less_highschool.head()
#
# NameError: name 'emp_lvl_less_highschool' is not defined
